# %%
from dataset import BaseDataset, BaseAugmentation
import torch
import utils
import matplotlib.pyplot as plt
import numpy as np

# %%
val_dataset = BaseDataset('../../../input/data', 'val.json')
transform = BaseAugmentation()
val_dataset.set_transform(transform)
val_loader = torch.utils.data.DataLoader(
        dataset=val_dataset,
        batch_size = 1,
        collate_fn = utils.collate_fn
    )
it = iter(val_loader)
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# loading annotations into memory...
# Done (t=0.87s)
# creating index...
# index created!
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {'Glass', 5}, {'Plastic', 6}, {8, 'Plastic bag'}]

# %%
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {'Paper', 2}, {'Plastic', 6}]

# %%
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {'General trash', 1}, {8, 'Plastic bag'}]

# %%
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {'Paper', 2}, {8, 'Plastic bag'}]

# %%
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {3, 'Paper pack'}, {8, 'Plastic bag'}]

# %%
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {'General trash', 1}, {'Paper', 2}, {'Plastic', 6}, {8, 'Plastic bag'}]

# %%
temp_images, temp_masks, image_infos = next(it)
image_infos = image_infos[0]
category_names = val_dataset.category_names

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Background'}, {'General trash', 1}, {'Paper', 2}, {3, 'Paper pack'}, {'Plastic', 6}, {'Styrofoam', 7}, {8, 'Plastic bag'}]
